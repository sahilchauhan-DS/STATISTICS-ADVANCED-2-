# %% [markdown]
# **THEORETICAL**

# %% [markdown]
# 1. What is hypothesis testing in statistics?
# a. Hypothesis testing is a method for making decisions or inferences about population parameters based on sample data.
# b. It involves formulating two hypotheses and using statistical evidence to accept or reject one of them.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
# a. The null hypothesis (H₀) represents the default or no-effect assumption (e.g., no difference or no relationship).
# b. The alternative hypothesis (H₁ or Ha) represents what you aim to support – a change, difference, or effect.
# c. Hypothesis testing evaluates whether data provides sufficient evidence to reject H₀ in favor of H₁.
#
# 3. What is the significance level in hypothesis testing, and why is it important?
# a. The significance level (α) is the threshold for rejecting the null hypothesis (commonly 0.05).
# b. It represents the probability of making a Type I error – rejecting a true null hypothesis.
# c. It controls the false positive rate in hypothesis testing.
#
# 4. What does a P-value represent in hypothesis testing?
# a. The P-value is the probability of obtaining a test statistic as extreme as or more extreme than the observed result, assuming the null hypothesis is true.
# b. It measures the strength of evidence against the null hypothesis.
#
# 5. How do you interpret the P-value in hypothesis testing?
# a. If the P-value ≤ α (e.g., 0.05), reject the null hypothesis – the result is statistically significant.
# b. If the P-value > α, fail to reject the null hypothesis – insufficient evidence to support the alternative.
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
# a. Type I error: Rejecting a true null hypothesis (false positive).
# b. Type II error: Failing to reject a false null hypothesis (false negative).
# c. There is a trade-off between the two; reducing one often increases the other.
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# a. A one-tailed test checks for a deviation in only one direction (e.g., mean > value).
# b. A two-tailed test checks for deviations in both directions (e.g., mean ≠ value).
# c. The choice depends on the research question or hypothesis.
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
# a. The Z-test is used to test hypotheses about population means or proportions when the population standard deviation is known.
# b. It assumes normal distribution or large sample sizes (n ≥ 30).
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
# a. Formula:
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# b. It represents how many standard errors the sample mean
# 𝑋
# ˉ
# X
# ˉ
#   is from the population mean
# 𝜇
# μ.
# c. It’s used to find the P-value and make decisions about the hypotheses.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
# a. The T-distribution is used when the sample size is small (typically n < 30) and the population standard deviation is unknown.
# b. It is wider and has heavier tails than the normal distribution.
# c. As sample size increases, it approaches the normal distribution.
#
# 11. What is the difference between a Z-test and a T-test?
# a. Z-test: Used when population standard deviation is known and/or sample size is large.
# b. T-test: Used when population standard deviation is unknown and sample size is small.
# c. Both test means but under different conditions.
#
# 12. What is the T-test, and how is it used in hypothesis testing?
# a. A T-test assesses whether the means of one or more groups differ significantly from each other or a known value.
# b. Types include one-sample, two-sample (independent), and paired t-tests.
# c. It uses the t-distribution to determine significance.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
# a. Both tests evaluate differences between means.
# b. The T-test is a generalization of the Z-test when the population variance is unknown.
# c. When sample size is large, both give similar results.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
# a. A confidence interval gives a range of plausible values for a population parameter.
# b. It reflects the uncertainty around a point estimate.
# c. If the interval includes the null value (e.g., 0 for differences), the result may not be statistically significant.
#
# 15. What is the margin of error, and how does it affect the confidence interval?
# a. The margin of error defines how much the estimate might vary due to sampling error.
# b. It determines the width of the confidence interval.
# c. Larger sample sizes reduce the margin of error.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
# a. Bayes' Theorem calculates the probability of a hypothesis given observed data.
# b. It combines prior beliefs with new evidence (posterior probability).
# c. Widely used in decision making, machine learning, and diagnostics.
#
# 17. What is the Chi-square distribution, and when is it used?
# a. The Chi-square distribution is a right-skewed distribution used in categorical data analysis.
# b. It’s applied in tests of independence, homogeneity, and goodness of fit.
# c. Based on the sum of squared standard normal variables.
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
# a. It tests whether observed frequencies differ from expected frequencies.
# b. Common in assessing how well data fits a theoretical distribution.
# c. Requires categorical data and sufficiently large sample sizes.
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
# a. The F-distribution is used to compare two variances.
# b. It is asymmetric and skewed to the right.
# c. It’s used in ANOVA and regression model comparisons.
#
# 20. What is an ANOVA test, and what are its assumptions?
# a. ANOVA (Analysis of Variance) compares the means of three or more groups.
# b. Assumptions:
#   i. Independence of observations
#   ii. Normality of the residuals
#   iii. Homogeneity of variances
#
# 21. What are the different types of ANOVA tests?
# a. One-way ANOVA – compares means across one factor.
# b. Two-way ANOVA – examines interaction between two factors.
# c. Repeated measures ANOVA – used when the same subjects are measured multiple times.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
# a. The F-test evaluates whether two population variances are significantly different.
# b. It is used in ANOVA and regression analysis.
# c. A large F-value suggests that the group means are not all equal.

# %% [markdown]
# **PRACTICAL 1**

# %%
# 1. Write a Python program to generate a random variable and display its value
import numpy as np

random_value = np.random.rand()  # Generates a value from a uniform distribution [0,1]
print("Random variable:", random_value)
# Out:
# Random variable: 0.09433336130365233

# %%
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)
import numpy as np
import matplotlib.pyplot as plt

values = np.arange(1, 7)
probabilities = np.full_like(values, 1/len(values), dtype=np.float64)

plt.stem(values, probabilities)
plt.title("Discrete Uniform Distribution PMF (e.g., fair die)")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %%
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
def bernoulli_pdf(p, x):
    return p if x == 1 else 1 - p

p = 0.7
x = 1
print(f"Bernoulli PDF P(X={x}) with p={p}: {bernoulli_pdf(p, x)}")
# Out:
# Bernoulli PDF P(X=1) with p=0.7: 0.7

# %%
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n, p = 10, 0.5
samples = binom.rvs(n, p, size=1000)

plt.hist(samples, bins=np.arange(n+2)-0.5, edgecolor='black', density=True)
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 5. Create a Poisson distribution and visualize it using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

mu = 4
samples = poisson.rvs(mu, size=1000)

plt.hist(samples, bins=np.arange(0, max(samples)+2)-0.5, edgecolor='black', density=True)
plt.title("Poisson Distribution Histogram (λ=4)")
plt.xlabel("Occurrences")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import numpy as np
import matplotlib.pyplot as plt

values = np.arange(1, 7)
pmf = np.full_like(values, 1/len(values), dtype=np.float64)
cdf = np.cumsum(pmf)

plt.step(values, cdf, where='mid')
plt.title("Discrete Uniform Distribution CDF")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
# 7. Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt

samples = np.random.uniform(0, 1, size=1000)

plt.hist(samples, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution [0, 1]")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 8. Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt

samples = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(samples, bins=30, edgecolor='black', density=True)
plt.title("Normal Distribution Histogram (mean=0, std=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 9. Write a Python function to calculate Z-scores from a dataset and plot them
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore

data = np.random.normal(100, 15, size=1000)
z_scores = zscore(data)

sns.histplot(z_scores, bins=30, kde=True)
plt.title("Z-scores of Normally Distributed Data")
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution
import numpy as np
import matplotlib.pyplot as plt

population = np.random.exponential(scale=2.0, size=100000)
sample_means = [np.mean(np.random.choice(population, size=30)) for _ in range(1000)]

plt.hist(sample_means, bins=30, density=True, edgecolor='black')
plt.title("Central Limit Theorem Demonstration (Exponential → Normal)")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
import numpy as np
import matplotlib.pyplot as plt

means = []
for _ in range(1000):
    sample = np.random.normal(loc=10, scale=5, size=30)
    means.append(np.mean(sample))

plt.hist(means, bins=30, density=True, edgecolor='black')
plt.title("CLT with Samples from Normal Distribution")
plt.xlabel("Sample Means")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y)
plt.title("Standard Normal Distribution (mean=0, std=1)")
plt.xlabel("Z")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %%
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution
from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

for i, prob in zip(x, pmf):
    print(f"P(X={i}) = {prob:.4f}")
# Out:
# P(X=0) = 0.0010
# P(X=1) = 0.0098
# P(X=2) = 0.0439
# P(X=3) = 0.1172
# P(X=4) = 0.2051
# P(X=5) = 0.2461
# P(X=6) = 0.2051
# P(X=7) = 0.1172
# P(X=8) = 0.0439
# P(X=9) = 0.0098
# P(X=10) = 0.0010

# %%
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
import numpy as np
from scipy.stats import norm

x = 115
mean = 100
std_dev = 15

z = (x - mean) / std_dev
prob = norm.cdf(z)

print(f"Z-score: {z:.2f}")
print(f"Probability that a value is less than {x}: {prob:.4f}")
# Out:
# Z-score: 1.00
# Probability that a value is less than 115: 0.8413

# %%
# 15. Implement hypothesis testing using Z-statistics for a sample dataset
import numpy as np
from scipy.stats import norm

sample = np.random.normal(loc=52, scale=10, size=50)
population_mean = 50
sample_mean = np.mean(sample)
std_dev = np.std(sample, ddof=1)
n = len(sample)

z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-statistic: {z:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Z-statistic: 0.75
# P-value: 0.4514

# %%
# 16. Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
from scipy.stats import norm

data = np.random.normal(loc=100, scale=15, size=50)
mean = np.mean(data)
std_err = np.std(data, ddof=1) / np.sqrt(len(data))
z = norm.ppf(0.975)

ci_lower = mean - z * std_err
ci_upper = mean + z * std_err

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval: (94.16, 103.69)

# %%
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
from scipy.stats import norm

data = np.random.normal(50, 10, 100)
mean = np.mean(data)
sem = np.std(data, ddof=1) / np.sqrt(len(data))
z_score = norm.ppf(0.975)

ci = (mean - z_score * sem, mean + z_score * sem)
print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(47.725773167668514), np.float64(51.0642898809941))

# %%
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x)

plt.plot(x, pdf)
plt.title("Normal Distribution PDF")
plt.xlabel("x")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
from scipy.stats import poisson

mu = 3
x = 5
cdf = poisson.cdf(x, mu)

print(f"P(X ≤ {x}) in a Poisson(λ=3): {cdf:.4f}")
# Out:
# P(X ≤ 5) in a Poisson(λ=3): 0.9161

# %%
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value
import numpy as np

data = np.random.uniform(0, 10, size=1000)
expected_value = np.mean(data)

print(f"Expected Value: {expected_value:.2f}")
# Out:
# Expected Value: 4.97

# %%
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(50, 5, 1000)
data2 = np.random.normal(50, 15, 1000)

print(f"Std Dev - Data1: {np.std(data1):.2f}, Data2: {np.std(data2):.2f}")

plt.hist(data1, bins=30, alpha=0.6, label="Std Dev = 5")
plt.hist(data2, bins=30, alpha=0.6, label="Std Dev = 15")
plt.legend()
plt.title("Comparison of Two Standard Deviations")
plt.grid(True)
plt.show()
# Out:
# Std Dev - Data1: 4.83, Data2: 15.01

# %% [markdown]
# **PRACTICAL 2**

# %%
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results
import numpy as np
from scipy.stats import norm

sample = np.random.normal(loc=52, scale=10, size=40)
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
pop_mean = 50

z = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(sample)))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-score: {z:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Z-score: 2.02
# P-value: 0.0438

# %%
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
from scipy.stats import ttest_1samp

data = np.random.normal(100, 15, 50)
statistic, p_value = ttest_1samp(data, 102)

print(f"T-statistic: {statistic:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# T-statistic: -1.33
# P-value: 0.1912

# %%
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean
import numpy as np
from scipy.stats import norm

data = np.random.normal(20, 5, 30)
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
pop_mean = 22

z = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(data)))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-statistic: {z:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Z-statistic: -2.19
# P-value: 0.0283

# %%
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

data = np.random.normal(102, 10, 50)
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
pop_mean = 100

z = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(data)))
p_value = 2 * (1 - norm.cdf(abs(z)))

# Visualization
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)
critical_z = norm.ppf(0.975)

plt.plot(x, y, label='Standard Normal Distribution')
plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
plt.axvline(critical_z, color='green', linestyle=':', label='Critical Value (±1.96)')
plt.axvline(-critical_z, color='green', linestyle=':')
plt.fill_between(x, y, where=(x <= -critical_z) | (x >= critical_z), color='lightgray', alpha=0.5, label='Rejection Region')
plt.legend()
plt.title("Two-Tailed Z-test Decision Region")
plt.grid(True)
plt.show()

# %%
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(mu0=100, mu1=105, sigma=10, n=30, alpha=0.05):
    se = sigma / np.sqrt(n)
    z_crit = norm.ppf(1 - alpha)
    x = np.linspace(90, 115, 1000)

    plt.plot(x, norm.pdf(x, mu0, se), label='H0 Distribution', color='blue')
    plt.plot(x, norm.pdf(x, mu1, se), label='H1 Distribution', color='orange')

    critical_value = mu0 + z_crit * se
    plt.axvline(critical_value, color='red', linestyle='--', label='Critical Value')

    plt.fill_between(x, 0, norm.pdf(x, mu0, se), where=(x >= critical_value), color='red', alpha=0.3, label='Type I Error (α)')
    plt.fill_between(x, 0, norm.pdf(x, mu1, se), where=(x < critical_value), color='purple', alpha=0.3, label='Type II Error (β)')

    plt.legend()
    plt.title("Type I and Type II Errors Visualization")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.show()

visualize_errors()

# %%
# 6. Write a Python program to perform an independent T-test and interpret the results
from scipy.stats import ttest_ind

group1 = np.random.normal(100, 10, 30)
group2 = np.random.normal(105, 12, 30)

t_stat, p_val = ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_val:.4f}")
# Out:
# T-statistic: -2.48
# P-value: 0.0159

# %%
# 7. Perform a paired sample T-test using Python and visualize the comparison results
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

before = np.random.normal(50, 5, 30)
after = before + np.random.normal(2, 2, 30)

t_stat, p_val = ttest_rel(before, after)

print(f"Paired T-test: T={t_stat:.2f}, P={p_val:.4f}")

plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.legend()
plt.title("Before vs After Treatment")
plt.grid(True)
plt.show()
# Out:
# Paired T-test: T=-7.76, P=0.0000

# %%
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python
import numpy as np
from scipy.stats import ttest_1samp, norm

data = np.random.normal(100, 15, 30)
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
pop_mean = 102

# Z-test
z = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(data)))
z_pval = 2 * (1 - norm.cdf(abs(z)))

# T-test
t_stat, t_pval = ttest_1samp(data, pop_mean)

print(f"Z-test: Z={z:.2f}, P={z_pval:.4f}")
print(f"T-test: T={t_stat:.2f}, P={t_pval:.4f}")
# Out:
# Z-test: Z=0.70, P=0.4828
# T-test: T=0.70, P=0.4884

# %%
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance
import numpy as np
from scipy.stats import norm

def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(len(data))
    z = norm.ppf((1 + confidence) / 2)
    return mean - z * std_err, mean + z * std_err

sample = np.random.normal(100, 10, 50)
ci = confidence_interval(sample)
print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(96.77762099334045), np.float64(103.35657542385341))

# %%
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data
import numpy as np
from scipy.stats import norm

data = np.random.normal(80, 15, 40)
confidence = 0.95
z = norm.ppf((1 + confidence) / 2)
std_err = np.std(data, ddof=1) / np.sqrt(len(data))
margin = z * std_err

print(f"Margin of Error (95% CI): {margin:.2f}")
# Out:
# Margin of Error (95% CI): 4.48

# %%
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# Bayes' Theorem: P(A|B) = (P(B|A) * P(A)) / P(B)

def bayes_theorem(p_a, p_b_given_a, p_b_given_not_a):
    # P(not A) = 1 - P(A)
    p_not_a = 1 - p_a
    # Total probability of B (P(B)) using the law of total probability
    p_b = (p_b_given_a * p_a) + (p_b_given_not_a * p_not_a)
    # Applying Bayes' Theorem to find P(A|B)
    p_a_given_b = (p_b_given_a * p_a) / p_b
    return p_a_given_b

# Example: A medical test for a rare disease
# P(Disease) = 0.01 (1% of population has the disease)
# P(Pos | Disease) = 0.99 (Test is 99% accurate for people with disease)
# P(Pos | No Disease) = 0.05 (5% false positive rate)

p_disease = 0.01  # Prior probability of disease
p_positive_given_disease = 0.99  # Likelihood of positive test result if the person has the disease
p_positive_given_no_disease = 0.05  # Likelihood of positive test result if the person doesn't have the disease

posterior = bayes_theorem(p_disease, p_positive_given_disease, p_positive_given_no_disease)

print(f"Probability of having disease given positive test result: {posterior:.4f}")
# Out:
# Probability of having disease given positive test result: 0.1667

# %%
# 12. Perform a Chi-square test for independence between two categorical variables in Python

import numpy as np
from scipy.stats import chi2_contingency

# Observed data for two categorical variables (e.g., gender and choice of product)
# The data is represented as a 2x2 contingency table
observed = np.array([[30, 10],   # Gender 1 (30 choose product A, 10 choose product B)
                     [15, 25]])  # Gender 2 (15 choose product A, 25 choose product B)

# Perform the chi-square test of independence
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

print(f"Chi-squared statistic: {chi2_stat:.2f}")
print(f"P-value: {p_val:.4f}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies: \n{expected}")
# Out:
# Chi-squared statistic: 9.96
# P-value: 0.0016
# Degrees of freedom: 1
# Expected frequencies:
# [[22.5 17.5]
#  [22.5 17.5]]

# %%
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[50, 30], [20, 40]])
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

print(f"Expected Frequencies: \n{expected}")
# Out:
# Expected Frequencies:
# [[40. 40.]
#  [30. 30.]]

# %%
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution
import numpy as np
from scipy.stats import chisquare

observed = np.array([10, 20, 30, 40])
expected = np.array([15, 15, 35, 35])

chi2_stat, p_val = chisquare(observed, expected)

print(f"Chi-squared statistic: {chi2_stat:.2f}")
print(f"P-value: {p_val:.4f}")
# Out:
# Chi-squared statistic: 4.76
# P-value: 0.1901
